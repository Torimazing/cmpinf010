# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None) #this makes the head() function not cut off any columns, so I can make sure every one is passed thuroughly

dog = pd.read_csv("dog_data.csv")
asb = pd.read_csv("asbestos.csv")
pub = pd.read_csv("public_areas.csv")
pop = pd.read_csv("us_2020.csv")
zips = pd.read_csv("zips.csv")

# %% [markdown]
# # Cleaning rows

# %%
zips.head()

# print(zips.columns)
zipcols = ['zip_type', 'state', 'state_fips',
       'county_fips', 'county_name', 's3dzip', 'lat', 'lon', 'empty_col',
       'tot_res_cnt', 'mfdu', 'sfdu', 'box_cnt', 'biz_cnt', 'relver', 'color',
       'globalid', 'shape_st_area', 'shape_st_length', 'objectid']
for col in zipcols:
    zips.drop(col , inplace=True, axis=1)
zips.head() # we now have a neighborhood name for each zip code in the city
# Out:
#      zip            name
# 0  15007      BAKERSTOWN
# 1  15014    BRACKENRIDGE
# 2  15015  BRADFORD WOODS
# 3  15018     BUENA VISTA
# 4  15034      DRAVOSBURG

# %%
dog.head()

#print(dog.columns)

dogcols = ['Breed', 'Color', 'DogName', 'ExpYear', 'ValidDate']
for col in dogcols:
    dog.drop(col , inplace=True, axis=1)
dog.head() # dogs now have a 'count' for each zip code
# Out:
#                   LicenseType  OwnerZip
# 0  Dog Lifetime Spayed Female     15137
# 1  Dog Lifetime Neutered Male     15129
# 2  Dog Lifetime Spayed Female     15129
# 3  Dog Lifetime Spayed Female     15140
# 4  Dog Lifetime Spayed Female     15238

# %%
#print(asb.columns)
asbcols = ['permit_number', 's_name', 's_address', 'city', 'p_fee',
       'pa_license_no', 'contractor_name', 'permit_specifications',
       'square_feet', 'is_the_building_occupied', 'i_date', 'e_date',
       'achd_inspector', 'latitude', 'longitude', 'permit_o_e_date']
for col in asbcols:
    asb.drop(col , inplace=True, axis=1)
asb.head() # keeping only the relevant columns
# Out:
#   z_code job_complete is_permit_date_extended project_type    status
# 0  15219            t                       f          DEM  COMPLETE
# 1  15208            f                       f          PAA   EXPIRED
# 2  15132            f                       f          DEM  COMPLETE
# 3  15132            f                       f          DEM  COMPLETE
# 4  15132            t                       f          DEM  COMPLETE

# %%
#print(pub.columns)
pub.head()
pubcols = ['x', 'y', 'fid', 'perimeter', 'publicbl_i', 'facility', 'facility_c',
       'address', 'city', 'class']
for col in pubcols:
    pub.drop(col , inplace=True, axis=1)
pub.head() # keeping only the relevant columns
# Out:
#    zipcode  municode
# 0    15205     100.0
# 1    15219     100.0
# 2    15206     100.0
# 3    15210     100.0
# 4    15116     944.0

# %%
print(pop.columns)
pop.head()

popcols = ['latitude',
       'longitude']
for col in popcols:
    pop.drop(col , inplace=True, axis=1)
pop.head() # keeping only the relevant columns
# Out:
# Index(['zip', 'population', 'population_density', 'city', 'state', 'latitude',
#        'longitude'],
#       dtype='object')
#      zip  population  population_density      city        state
# 0  10162        1726           151834.77  New York     New York
# 1  10028       44987           126067.69  New York     New York
# 2  10128       59856           122356.52  New York     New York
# 3   8625        1834           115477.17   Trenton   New Jersey
# 4  10031       60221           101100.03  New York     New York

# %% [markdown]
# # Dropping Null

# %%
tables = [zips, dog, asb, pop, pub]
tablename = ['zips', 'dog', 'asb', 'pop', 'pub']
count = 0
for table in tables:
    print(tablename[count])
    print(table.isnull().sum())
    count += 1
count = 0
for table in tables:
    print(tablename[count])
    print(table.size)
    count += 1
# Out:
# zips
# zip     0
# name    0
# dtype: int64
# dog
# LicenseType    0
# OwnerZip       0
# dtype: int64
# asb
# z_code                      15
# job_complete               286
# is_permit_date_extended    312
# project_type                 0
# status                       0
# dtype: int64
# pop
# zip                   0
# population            0
# population_density    0
# city                  0
# state                 0
# dtype: int64
# pub
# zipcode      0
# municode    53
# dtype: int64
# zips
# 250
# dog
# 82836
# asb
# 36555
# pop
# 158500
# pub
# 506

# %%
asb = asb.dropna()
pub = pub.dropna()

# %% [markdown]
# # Find totals

# %%
dog = dog.rename(columns = {"OwnerZip":"zip"})
dogs = dog.value_counts("zip").to_frame()
dogs.reset_index(inplace=True)
dogs = dogs.rename(columns = {0:"num_dogs"})
dogs = dogs.merge(pop)
dogs.head(20)
# Out:
#       zip  num_dogs  population  population_density             city  \
# 0   15237      2418       42597             1714.83       Pittsburgh
# 1   15236      1701       30630             3072.10       Pittsburgh
# 2   15108      1441       37804              943.40       Coraopolis
# 3   15102      1397       30825             2956.30      Bethel Park
# 4   15044      1388       23196              559.16         Gibsonia
# 5   15235      1378       39126             2576.18       Pittsburgh
# 6   15239      1326       21108             1229.97       Pittsburgh
# 7   15122      1298       21861             1565.84     West Mifflin
# 8   15101      1282       24323             1227.85     Allison Park
# 9   15227      1254       29621             4843.37       Pittsburgh
# 10  15146      1211       29394             1475.36      Monroeville
# 11  15143      1204       16518              463.99        Sewickley
# 12  15090      1170       18252              833.98          Wexford
# 13  15037       954       11676              441.23        Elizabeth
# 14  15025       911       17341              991.51         Clairton
# 15  15241       873       20616             2014.70       Pittsburgh
# 16  15147       834       18442             1980.63           Verona
# 17  15229       810       13677             3754.93       Pittsburgh
# 18  15065       759       11996             1003.31  Natrona Heights
# 19  15120       749       20437             4505.69        Homestead
#
#             state
# 0    Pennsylvania
# 1    Pennsylvania
# 2    Pennsylvania
# 3    Pennsylvania
# 4    Pennsylvania
# 5    Pennsylvania
# 6    Pennsylvania
# 7    Pennsylvania
# 8    Pennsylvania
# 9    Pennsylvania
# 10   Pennsylvania
# 11   Pennsylvania
# 12   Pennsylvania
# 13   Pennsylvania
# 14   Pennsylvania
# 15   Pennsylvania
# 16   Pennsylvania
# 17   Pennsylvania
# 18   Pennsylvania
# 19   Pennsylvania

# %%
asb = asb.rename(columns = {"z_code":"zip"})
#asb = asb.merge(pop)
asb.dtypes
asb['zip'] = asb['zip'].astype('int64')
asb = asb.value_counts("zip").to_frame()
asb.reset_index(inplace=True)
asb = asb.rename(columns = {0:"asbestos"})
asb = asb.merge(pop)
asb.head(15)
# Out:
#       zip  asbestos  population  population_density          city  \
# 0   15213       601       28320            12135.47    Pittsburgh
# 1   15132       569       26131             4629.54    Mckeesport
# 2   15219       563       19204             8488.98    Pittsburgh
# 3   15212       403       31850             4985.21    Pittsburgh
# 4   15222       291        1999             2255.97    Pittsburgh
# 5   15206       219       32482             6735.79    Pittsburgh
# 6   15025       213       17341              991.51      Clairton
# 7   15221       189       36387             5660.09    Pittsburgh
# 8   15122       154       21861             1565.84  West Mifflin
# 9   15208       135       13352             7244.66    Pittsburgh
# 10  15146       129       29394             1475.36   Monroeville
# 11  15237       128       42597             1714.83    Pittsburgh
# 12  15224       126       12095            12931.62    Pittsburgh
# 13  15210       125       31216             7059.74    Pittsburgh
# 14  15104       115       11434             4569.34      Braddock
#
#             state
# 0    Pennsylvania
# 1    Pennsylvania
# 2    Pennsylvania
# 3    Pennsylvania
# 4    Pennsylvania
# 5    Pennsylvania
# 6    Pennsylvania
# 7    Pennsylvania
# 8    Pennsylvania
# 9    Pennsylvania
# 10   Pennsylvania
# 11   Pennsylvania
# 12   Pennsylvania
# 13   Pennsylvania
# 14   Pennsylvania

# %%
pub = pub.rename(columns = {"zipcode":"zip"})
pub = pub.value_counts("zip").to_frame()
pub.reset_index(inplace=True)
pub = pub.rename(columns = {0:"public_builds"})
pub = pub.merge(pop)
pub.head(15)
# Out:
#       zip  public_builds  population  population_density        city  \
# 0   15217             11       26425             7129.47  Pittsburgh
# 1   15143              9       16518              463.99   Sewickley
# 2   15222              8        1999             2255.97  Pittsburgh
# 3   15221              8       36387             5660.09  Pittsburgh
# 4   15206              8       32482             6735.79  Pittsburgh
# 5   15205              7       22586             2350.14  Pittsburgh
# 6   15212              7       31850             4985.21  Pittsburgh
# 7   15219              6       19204             8488.98  Pittsburgh
# 8   15202              5       21022             4460.81  Pittsburgh
# 9   15120              4       20437             4505.69   Homestead
# 10  15106              4       19074             1729.75    Carnegie
# 11  15220              4       19693             3577.47  Pittsburgh
# 12  15214              4       17519             3810.01  Pittsburgh
# 13  15210              4       31216             7059.74  Pittsburgh
# 14  15084              3       10542              372.83    Tarentum
#
#             state
# 0    Pennsylvania
# 1    Pennsylvania
# 2    Pennsylvania
# 3    Pennsylvania
# 4    Pennsylvania
# 5    Pennsylvania
# 6    Pennsylvania
# 7    Pennsylvania
# 8    Pennsylvania
# 9    Pennsylvania
# 10   Pennsylvania
# 11   Pennsylvania
# 12   Pennsylvania
# 13   Pennsylvania
# 14   Pennsylvania

# %%
df = dogs
df = df.merge(asb)
df = df.merge(pub)
df.head(60)
print(df.columns)
# Out:
# Index(['zip', 'num_dogs', 'population', 'population_density', 'city', 'state',
#        'asbestos', 'public_builds'],
#       dtype='object')

# %%
df.drop('state', inplace=True, axis=1)
df.drop('population_density', inplace=True, axis=1)
df.head()
# Out:
#      zip  num_dogs  population         city  asbestos  public_builds
# 0  15237      2418       42597   Pittsburgh       128              3
# 1  15236      1701       30630   Pittsburgh        98              2
# 2  15108      1441       37804   Coraopolis       110              3
# 3  15102      1397       30825  Bethel Park        50              1
# 4  15044      1388       23196     Gibsonia        23              1

# %%
df['dogs_per'] = df['num_dogs'].div(df['population'])
df['dogs_per'] = df['dogs_per'].mul(1000)

# %%
df['asb_per'] = df['asbestos'].div(df['population'])
df['asb_per'] = df['asb_per'].mul(1000)

# %%
df['build_per'] = df['public_builds'].div(df['population'])
df['build_per'] = df['build_per'].mul(1000)

# %%
df['final_rank'] = df['build_per'].add(df['asb_per'])
df['final_rank'] = df['final_rank'].add(df['dogs_per'])
df = df.sort_values(by = ['final_rank'], ascending=False)
df.head()
# Out:
#       zip  num_dogs  population        city  asbestos  public_builds  \
# 81  15222         3        1999  Pittsburgh       291              8
# 69  15086        24         284  Warrendale         4              1
# 51  15034       124        2015  Dravosburg        61              1
# 13  15037       954       11676   Elizabeth        20              3
# 26  15133       537        6816  Mckeesport        15              2
#
#      dogs_per     asb_per  build_per  final_rank
# 81   1.500750  145.572786   4.002001  151.075538
# 69  84.507042   14.084507   3.521127  102.112676
# 51  61.538462   30.272953   0.496278   92.307692
# 13  81.706064    1.712915   0.256937   83.675916
# 26  78.785211    2.200704   0.293427   81.279343

# %% [markdown]
# From this final ranking, zipcode 15222 a.k.a Pittsburgh's Strip District is the best place to share a neighborhood with other people.
